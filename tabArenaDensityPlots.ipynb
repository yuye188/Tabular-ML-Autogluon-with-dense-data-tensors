# %% [markdown]
# # Import modules

# %%
from TabArenaIterator import TabArenaIterator
import pandas as pd
import numpy as np
import plotly.express as px
import json
import plotly.graph_objects as go

# %% [markdown]
# # Iterate all TabArena datasets for the density plots

# %%
# Read previously saved results (calculated from getDensityTable.ipynb / section 'Iteration of all datasets from TabArena')
final_table = pd.read_csv('./data folder/results files/final_table.csv')
all_densities = json.load( open( "./data folder/results files/all_densities.json" ) )
display(final_table)
#all_densities
# Out:
#     dataset_id                                dataset_name  \
# 0        46904                          airfoil_self_noise
# 1        46905                      Amazon_employee_access
# 2        46906                                      anneal
# 3        46907            Another-Dataset-on-used-Fiat-500
# 4        46908                                  APSFailure
# 5        46910                              bank-marketing
# 6        46911                         Bank_Customer_Churn
# 7        46912                                 Bioresponse
# 8        46913            blood-transfusion-service-center
# 9        46915                                       churn
# 10       46916                 coil2000_insurance_policies
# 11       46917               concrete_compressive_strength
# 12       46918                                    credit-g
# 13       46919                 credit_card_clients_default
# 14       46920            customer_satisfaction_in_airline
# ...

# %%
# function to get density information and plot for a specific dataset
def get_density(dataset_id, final_table, all_densities, show_plot=False):
    dataset = final_table[final_table['dataset_id'] == dataset_id]
    densities = all_densities.get(str(dataset_id))

    print("Total features:", dataset['original_number_features'].iloc[0], ", Total rows:", dataset['original_number_rows'].iloc[0])
    print("Original density:", dataset['original_density'].iloc[0])
    #print()
    print("Features left:", dataset['final_number_features'].iloc[0], ", Rows left:", dataset['final_number_rows'].iloc[0])
    print("Final density:", dataset['final_density'].iloc[0])
    print()

    if show_plot:
        fig = px.line(
                x=range(0, len(densities), 1),
                y=densities,
                labels={"x": "Number features dropped", "y": "Density"},
            )
        fig.show()

# %%
# iterate over TabArena datasets and get density plots
tabArenaURL = 'https://raw.githubusercontent.com/TabArena/tabarena_dataset_curation/refs/heads/main/dataset_creation_scripts/metadata/tabarena_dataset_metadata.csv'
iterator = TabArenaIterator(tabArenaURL)

for row, df in iterator:
    dataset_id = row['dataset_id']
    print('dataset_id:', dataset_id)

    get_density(dataset_id, final_table, all_densities, show_plot=True)
# Out:
# dataset_id: 46904
# Total features: 5 , Total rows: 1503
# Original density: 0.0010519022423784
# Features left: 4 , Rows left: 1503
# Final density: 0.1104497354497354
# dataset_id: 46905
# Total features: 9 , Total rows: 32769
# Original density: 5.4331464888837344e-21
# Features left: 1 , Rows left: 67
# Final density: 1.0
# dataset_id: 46906
# Total features: 38 , Total rows: 886
# Original density: 6.763894527119904e-16
# Features left: 13 , Rows left: 9
# Final density: 0.140625
# dataset_id: 46907
# Total features: 7 , Total rows: 1515
# Original density: 5.646737052785582e-10
# Features left: 3 , Rows left: 34
# Final density: 0.3541666666666667
# dataset_id: 46908
# Total features: 170 , Total rows: 76000
# Original density: 0.0
# Features left: 3 , Rows left: 52
# Final density: 0.8666666666666667
# dataset_id: 46910
# Total features: 13 , Total rows: 44905
# Original density: 5.349772965830006e-12
# Features left: 8 , Rows left: 2533
# Final density: 0.1832320601851851
# ...

# %% [markdown]
# # Analysis of results

# %%
# calculate improvement columns
def calculateInitialFinalImprovement(x):
    if pd.notna(x.initial_XGB_r2):
        return (x.final_XGB_r2 - x.initial_XGB_r2)/abs(x.initial_XGB_r2) * 100
    else:
        return (x.final_XGB_normalized_accuracy - x.initial_XGB_normalized_accuracy)/abs(x.initial_XGB_normalized_accuracy) * 100 
final_table['final_improvement_xgb'] = final_table.apply(lambda x : calculateInitialFinalImprovement(x), axis=1)
final_table['final_improvement_accuracy'] = final_table.apply(lambda x : (x.final_XGB_normalized_accuracy - x.final_NN_TORCH_normalized_accuracy)/x.final_NN_TORCH_normalized_accuracy * 100, axis=1)
final_table['final_improvement_r2'] = final_table.apply(lambda x : (x.final_XGB_r2 - x.final_NN_TORCH_r2)/x.final_NN_TORCH_r2 * 100, axis=1)
final_table
# Out:
#     dataset_id                                dataset_name  \
# 0        46904                          airfoil_self_noise
# 1        46905                      Amazon_employee_access
# 2        46906                                      anneal
# 3        46907            Another-Dataset-on-used-Fiat-500
# 4        46908                                  APSFailure
# 5        46910                              bank-marketing
# 6        46911                         Bank_Customer_Churn
# 7        46912                                 Bioresponse
# 8        46913            blood-transfusion-service-center
# 9        46915                                       churn
# 10       46916                 coil2000_insurance_policies
# 11       46917               concrete_compressive_strength
# 12       46918                                    credit-g
# 13       46919                 credit_card_clients_default
# 14       46920            customer_satisfaction_in_airline
# ...

# %%
# filter datasets with at least 3 features and 30 rows after density improvement process
final_table_filtered = final_table[(final_table['final_number_features'] >= 3) & (final_table['final_number_rows'] >= 30)]
final_table_filtered
# Out:
#     dataset_id                                dataset_name  \
# 0        46904                          airfoil_self_noise
# 3        46907            Another-Dataset-on-used-Fiat-500
# 4        46908                                  APSFailure
# 5        46910                              bank-marketing
# 6        46911                         Bank_Customer_Churn
# 7        46912                                 Bioresponse
# 9        46915                                       churn
# 12       46918                                    credit-g
# 13       46919                 credit_card_clients_default
# 14       46920            customer_satisfaction_in_airline
# 17       46923                                    diamonds
# 18       46924                       E-CommereShippingData
# 19       46927                                Fitness_Club
# 20       46928                          Food_Delivery_Time
# 21       46929                            GiveMeSomeCredit
# ...

# %%
# get histogram comparing original_density and final_density
fig = go.Figure()

fig.add_trace(go.Histogram(x=final_table['final_density'], name="Final_density", texttemplate="%{y}"))
fig.add_trace(go.Histogram(x=final_table['original_density'], name="Original_density", texttemplate="%{y}"))

# The two histograms are drawn on top of another
fig.update_layout(barmode='stack', bargap=0.1)
fig.update_layout(
    title='Comparison of Original vs Final Density',
        xaxis=dict(
            title=dict(
                text="Density"
            )
        ),
        yaxis=dict(
            title=dict(
                text="Count"
            )
        )
)
fig.show()

# %%
# get box plots comparing initial and final model performances
fig = go.Figure()
fig.add_trace(go.Box(y=final_table['initial_XGB_normalized_accuracy'], name='initial_XGB_normalized_accuracy', boxmean=True))
fig.add_trace(go.Box(y=final_table['final_XGB_normalized_accuracy'], name='final_XGB_normalized_accuracy', boxmean=True))
fig.add_trace(go.Box(y=final_table['initial_NN_TORCH_normalized_accuracy'], name = 'initial_NN_TORCH_normalized_accuracy', boxmean=True))
fig.add_trace(go.Box(y=final_table['final_NN_TORCH_normalized_accuracy'], name = 'final_NN_TORCH_normalized_accuracy', boxmean=True))

fig.add_trace(go.Box(y=final_table['initial_XGB_r2'], name='initial_XGB_r2', boxmean=True))
fig.add_trace(go.Box(y=final_table['final_XGB_r2'], name='final_XGB_r2', boxmean=True))
fig.add_trace(go.Box(y=final_table['initial_NN_TORCH_r2'], name = 'initial_NN_TORCH_r2', boxmean=True))
fig.add_trace(go.Box(y=final_table['final_NN_TORCH_r2'], name = 'final_NN_TORCH_r2', boxmean=True))

fig.update_layout(title='Comparison of Initial vs Final Model Performances')
fig.show()

# %%
# check datasets where at least one model has final normalized accuracy > 0.6
final_table[(final_table['final_XGB_normalized_accuracy'] > 0.6) | (final_table['final_NN_TORCH_normalized_accuracy'] > 0.6)]
# Out:
#     dataset_id               dataset_name  original_number_features  \
# 4        46908                 APSFailure                       170
# 5        46910             bank-marketing                        13
# 6        46911        Bank_Customer_Churn                        10
# 19       46927               Fitness_Club                         6
# 25       46933              hiva_agnostic                      1617
# 29       46938    Is-this-a-good-customer                        13
# 34       46980                        MIC                       111
# 35       46969               NATICUSdroid                        86
# 36       46947  online_shoppers_intention                        17
# 43       46956              seismic-bumps                        15
# 48       46963           website_phishing                         9
#
#     final_number_features  original_number_rows  final_number_rows  \
# 4                       3                 76000                 52
# ...

# %%
# check datasets where at least one model has final r2 > 0.6
final_table[(final_table['final_XGB_r2'] > 0.6) | (final_table['final_NN_TORCH_r2'] > 0.6)]
# Out:
#     dataset_id                   dataset_name  original_number_features  \
# 0        46904             airfoil_self_noise                         5
# 23       46931  healthcare_insurance_expenses                         6
#
#     final_number_features  original_number_rows  final_number_rows  \
# 0                       4                  1503               1503
# 23                      5                  1335                986
#
#     original_density  final_density binary_feature  initial_XGB_r2  ...  \
# 0           0.001052       0.110450            NaN        0.950645  ...
# 23          0.000540       0.218528            sex        0.806058  ...
#
#     final_XGB_normalized_accuracy  initial_NN_TORCH_r2  \
# 0                             NaN             0.947991
# 23                            NaN             0.803626
#
#     initial_NN_TORCH_accuracy  initial_NN_TORCH_normalized_accuracy  \
# 0                         NaN                                   NaN
# ...

# %%
# scatter plot of final_density vs improvement in normalized accuracy
fig = px.scatter(final_table, x='final_density', y='final_improvement_accuracy')
fig.update_layout(
        xaxis=dict(
            title=dict(
                text="Final Density"
            )
        ),
        yaxis=dict(
            title=dict(
                text="Improvement in Normalized Accuracy (%)"
            )
        )
)
fig.update_layout(title='Final_density vs improvement in normalized accuracy')
fig.show()

# %%
import plotly.express as px
fig = px.scatter(final_table, x='final_density', y='final_improvement_r2')
fig.update_layout(
        xaxis=dict(
            title=dict(
                text="Final Density"
            )
        ),
        yaxis=dict(
            title=dict(
                text="Improvement in R2 (%)"
            )
        )
)
fig.update_layout(title='Final_density vs improvement in R2')
fig.show()
