# %%
from TabArenaIterator import TabArenaIterator
import pandas as pd
import numpy as np

final_table = pd.DataFrame(columns=['dataset_id', 'dataset_name', 
                                    'original_number_features', 'final_number_features',
                                    'original_number_rows', 'final_number_rows',
                                    'original_density', 'final_density', 
                                    'initial_r2', 'accuracy_initial',
                                    'r2', 'accuracy'])

tabArenaURL = 'https://raw.githubusercontent.com/TabArena/tabarena_dataset_curation/refs/heads/main/dataset_creation_scripts/metadata/tabarena_dataset_metadata.csv'
iterator = TabArenaIterator(tabArenaURL)
for row, df in iterator:
    print(row['dataset_id'])

    # Obtain the dense df and informations about the changes
    dense_df, infos = getDensitiesPlot(df, row['target_feature'], density_threshold=0.1, show_fig=False)

    infos['dataset_id'] = row['dataset_id']
    infos['dataset_name'] = row['dataset_name']

    # Append the row to the final table
    final_table.loc[len(final_table)] = infos
# Out:
# 46904
# Total features: 5 Total rows: 1503
# Original density: 0.0010519022423784328
#
# Features left: 4 Rows left: 1503
# Final density: 0.11044973544973545
#
# 46905
# Total features: 9 Total rows: 32769
# Original density: 5.4331464888837344e-21
#
# Features left: 1 Rows left: 67
# Final density: 1.0
#
# 46906
# Total features: 38 Total rows: 886
# Original density: 6.763894527119904e-16
#
# Features left: 13 Rows left: 8
# Final density: 0.125
#
# 46907
# Total features: 7 Total rows: 1515
# Original density: 5.646737052785582e-10
#
# Features left: 3 Rows left: 34
# Final density: 0.3541666666666667
#
# 46908
# Total features: 170 Total rows: 76000
# Original density: 0.0
#
# Features left: 3 Rows left: 52
# Final density: 0.8666666666666667
#
# 46910
# Total features: 13 Total rows: 44905
# Original density: 5.349772965830006e-12
#
# Features left: 8 Rows left: 2533
# Final density: 0.18323206018518517
#
# 46911
# Total features: 10 Total rows: 10000
# Original density: 4.6085769342056656e-12
#
# Features left: 6 Rows left: 723
# Final density: 0.6846590909090909
#
# 46912
# Total features: 1776 Total rows: 3751
# Original density: 0.0
#
# Features left: 11 Rows left: 255
# Final density: 0.12451171875
#
# 46913
# Total features: 4 Total rows: 502
# Original density: 0.0001906424193814223
#
# Features left: 2 Rows left: 188
# Final density: 0.18377321603128055
#
# 46915
# Total features: 19 Total rows: 5000
# Original density: 2.774980106523841e-36
#
# Features left: 5 Rows left: 625
# Final density: 0.24801587301587302
#
# 46916
# Total features: 85 Total rows: 8261
# Original density: 4.188386241439141e-67
#
# Features left: 7 Rows left: 29
# Final density: 0.10069444444444445
#
# 46917
# Total features: 8 Total rows: 996
# Original density: 3.0385513323393077e-15
#
# Features left: 2 Rows left: 452
# Final density: 0.20829493087557605
#
# 46918
# Total features: 20 Total rows: 1000
# Original density: 1.4033527721394342e-13
#
# Features left: 7 Rows left: 164
# Final density: 0.18981481481481483
#
# 46919
# Total features: 23 Total rows: 29944
# Original density: 4.9283839727975495e-57
#
# Features left: 4 Rows left: 187
# Final density: 0.3339285714285714
#
# 46920
# Total features: 21 Total rows: 129880
# Original density: 1.8612414495883584e-18
#
# Features left: 8 Rows left: 8960
# Final density: 0.11522633744855967
#
# 46921
# Total features: 8 Total rows: 768
# Original density: 1.1174982314123598e-13
#
# Features left: 2 Rows left: 283
# Final density: 0.3541927409261577
#
# 46922
# Total features: 47 Total rows: 71518
# Original density: 7.57843832073672e-37
#
# Features left: 9 Rows left: 7
# Final density: 0.109375
#
# 46923
# Total features: 9 Total rows: 53595
# Original density: 2.616386759811203e-13
#
# Features left: 3 Rows left: 276
# Final density: 0.9857142857142858
#
# 46924
# Total features: 10 Total rows: 10999
# Original density: 9.03257841376853e-09
#
# Features left: 7 Rows left: 4761
# Final density: 0.22041666666666668
#
# 46927
# Total features: 6 Total rows: 1499
# Original density: 1.051149451208826e-05
#
# Features left: 4 Rows left: 176
# Final density: 0.11027568922305764
#
# 46928
# Total features: 9 Total rows: 45242
# Original density: 5.407391379869e-16
#
# Features left: 4 Rows left: 3221
# Final density: 0.3268060064935065
#
# 46929
# Total features: 10 Total rows: 149354
# Original density: 1.066472191353621e-19
#
# Features left: 3 Rows left: 323
# Final density: 0.11945266272189349
#
# 46930
# Total features: 30 Total rows: 2400
# Original density: 4.281293536606587e-90
#
# Features left: 1 Rows left: 781
# Final density: 1.0
#
# 46931
# Total features: 6 Total rows: 1335
# Original density: 0.0005399227364497593
#
# Features left: 5 Rows left: 986
# Final density: 0.21852836879432624
#
# 46932
# Total features: 23 Total rows: 9871
# Original density: 1.4832573002592818e-35
#
# Features left: 3 Rows left: 184
# Final density: 0.13529411764705881
#
# 46933
# Total features: 1617 Total rows: 3825
# Original density: 0.0
#
# Features left: 9 Rows left: 63
# Final density: 0.123046875
#
# 46934
# Total features: 8 Total rows: 20640
# Original density: 5.234241194407872e-22
#
# Features left: 2 Rows left: 11032
# Final density: 0.25136711629602626
#
# 46935
# Total features: 12 Total rows: 19084
# Original density: 5.30889048214203e-10
#
# Features left: 6 Rows left: 1731
# Final density: 0.1839923469387755
#
# 46937
# Total features: 24 Total rows: 12587
# Original density: 1.445596993304525e-11
#
# Features left: 9 Rows left: 178
# Final density: 0.1545138888888889
#
# 46938
# Total features: 13 Total rows: 1723
# Original density: 1.3356526487161817e-10
#
# Features left: 7 Rows left: 444
# Final density: 0.20555555555555555
#
# 46939
# Total features: 212 Total rows: 50000
# Original density: 0.0
#
# Features left: 8 Rows left: 14
# Final density: 0.109375
#
# 46940
# Total features: 25 Total rows: 2039
# Original density: 3.46008068054626e-32
#
# Features left: 8 Rows left: 67
# Final density: 0.11631944444444445
#
# 46941
# Total features: 6 Total rows: 416
# Original density: 7.372958257713248e-06
#
# Features left: 2 Rows left: 40
# Final density: 0.3125
#
# 46942
# Total features: 15 Total rows: 13776
# Original density: 1.011417240408681e-44
#
# Features left: 4 Rows left: 2812
# Final density: 0.24409722222222222
#
# 46980
# Total features: 111 Total rows: 1699
# Original density: 1.038332178849761e-68
#
# Features left: 5 Rows left: 37
# Final density: 0.22839506172839505
#
# 46969
# Total features: 86 Total rows: 7395
# Original density: 9.557813484108812e-23
#
# Features left: 9 Rows left: 69
# Final density: 0.134765625
#
# 46947
# Total features: 17 Total rows: 12205
# Original density: 1.3093726543475288e-29
#
# Features left: 5 Rows left: 374
# Final density: 0.14429012345679013
#
# 46949
# Total features: 9 Total rows: 43974
# Original density: 4.142388833151155e-35
#
# Features left: 1 Rows left: 341
# Final density: 1.0
#
# 46950
# Total features: 64 Total rows: 5850
# Original density: 9.503573095074777e-236
#
# Features left: 1 Rows left: 3255
# Final density: 1.0003073140749847
#
# 46952
# Total features: 41 Total rows: 1051
# Original density: 2.447263710241777e-63
#
# Features left: 5 Rows left: 15
# Final density: 0.15625
#
# 46953
# Total features: 1024 Total rows: 5259
# Original density: 2.925415855472343e-305
#
# Features left: 9 Rows left: 53
# Final density: 0.103515625
#
# 46954
# Total features: 6 Total rows: 774
# Original density: 7.633914023940202e-10
#
# Features left: 2 Rows left: 23
# Final density: 0.6571428571428571
#
# 46955
# Total features: 11 Total rows: 78053
# Original density: 2.0754355569286495e-42
#
# Features left: 2 Rows left: 6000
# Final density: 1.0
#
# 46956
# Total features: 15 Total rows: 2578
# Original density: 9.400295346125563e-18
#
# Features left: 6 Rows left: 53
# Final density: 0.1840277777777778
#
# 46958
# Total features: 60 Total rows: 3005
# Original density: 6.838044444444444e-38
#
# Features left: 7 Rows left: 2519
# Final density: 0.15374755859375
#
# 46960
# Total features: 36 Total rows: 4424
# Original density: 1.2905192552173215e-40
#
# Features left: 9 Rows left: 175
# Final density: 0.11393229166666667
#
# 46961
# Total features: 81 Total rows: 15170
# Original density: 3.872284267669358e-287
#
# Features left: 2 Rows left: 45
# Final density: 0.7142857142857143
#
# 46962
# Total features: 94 Total rows: 6819
# Original density: 0.0
#
# Features left: 2 Rows left: 389
# Final density: 0.510498687664042
#
# 46963
# Total features: 9 Total rows: 676
# Original density: 0.0772748056698674
#
# Features left: 8 Rows left: 558
# Final density: 0.19135802469135801
#
# 46964
# Total features: 12 Total rows: 5320
# Original density: 4.506093482946806e-22
#
# Features left: 3 Rows left: 2368
# Final density: 0.12550349798600804
#
# 46979
# Total features: 21 Total rows: 8824
# Original density: 3.679058450207553e-50
#
# Features left: 2 Rows left: 227
# Final density: 0.13757575757575757

# %%
def getDensitiesPlot(df, target_feature, density_threshold=0.1, show_fig = False):
    # Drop the target column and duplicated rows
    df_copy = df.copy().drop(columns=target_feature).drop_duplicates()
    densities = []

    # Calculate the original dataset informations
    original_number_features = len(df_copy.columns)
    original_number_rows = len(df_copy)
    print('Total features:', original_number_features, 'Total rows:', original_number_rows)

    # Calculate the orignial density
    total = 1
    for i in df_copy.nunique().values:
        total = np.multiply(total, i, dtype=object)
    original_density = len(df_copy)/total
    print('Original density:', original_density)
    print()
    densities.append(original_density)

    # Dropping all available columns one by one until the threshold is chased
    for feature, cardinality in df_copy.nunique().sort_values(ascending=False).items():

        # Drop the corresponding column
        df_copy = df_copy.drop(columns=feature).drop_duplicates()
        
        # Calculate agian the density
        total = 1
        for i in df_copy.nunique().values:
            total = np.multiply(total, i, dtype=object)

        density = len(df_copy)/total
        densities.append(density)

        # Check the requirement to stop dropping columns
        if density > density_threshold:
            break
    
    # Calculate the final dataset informations
    final_number_features = len(df_copy.columns)
    final_number_rows = len(df_copy)
    print('Features left:', final_number_features, 'Rows left:', final_number_rows)
    print('Final density:', density)
    print()

    # Plot the column dropping process
    if show_fig:
        fig = px.line(x=range(0, len(densities), 1), y=densities, labels={'x':'Number features dropped', 'y':'Density'})
        fig.show()

    # Return the final dataset and the change informations 
    return df_copy, {'original_number_features': original_number_features,
                     'original_number_rows' : original_number_rows,
                     'original_density': original_density, 
                     'final_number_features': final_number_features,
                     'final_number_rows': final_number_rows,
                     'final_density': density}

# %%
final_table
# Out:
#     dataset_id                                dataset_name  \
# 0        46904                          airfoil_self_noise
# 1        46905                      Amazon_employee_access
# 2        46906                                      anneal
# 3        46907            Another-Dataset-on-used-Fiat-500
# 4        46908                                  APSFailure
# 5        46910                              bank-marketing
# 6        46911                         Bank_Customer_Churn
# 7        46912                                 Bioresponse
# 8        46913            blood-transfusion-service-center
# 9        46915                                       churn
# 10       46916                 coil2000_insurance_policies
# 11       46917               concrete_compressive_strength
# 12       46918                                    credit-g
# 13       46919                 credit_card_clients_default
# 14       46920            customer_satisfaction_in_airline
# 15       46921                                    diabetes
# 16       46922                               Diabetes130US
# 17       46923                                    diamonds
# 18       46924                       E-CommereShippingData
# 19       46927                                Fitness_Club
# 20       46928                          Food_Delivery_Time
# 21       46929                            GiveMeSomeCredit
# 22       46930       hazelnut-spread-contaminant-detection
# 23       46931               healthcare_insurance_expenses
# 24       46932                                       heloc
# 25       46933                               hiva_agnostic
# 26       46934                                      houses
# 27       46935  HR_Analytics_Job_Change_of_Data_Scientists
# 28       46937            in_vehicle_coupon_recommendation
# 29       46938                     Is-this-a-good-customer
# 30       46939                          kddcup09_appetency
# 31       46940                          Marketing_Campaign
# 32       46941                        maternal_health_risk
# 33       46942                               miami_housing
# 34       46980                                         MIC
# 35       46969                                NATICUSdroid
# 36       46947                   online_shoppers_intention
# 37       46949                      physiochemical_protein
# 38       46950                 polish_companies_bankruptcy
# 39       46952                                 qsar-biodeg
# 40       46953                                 QSAR-TID-11
# 41       46954                          QSAR_fish_toxicity
# 42       46955                                      SDSS17
# 43       46956                               seismic-bumps
# 44       46958                                      splice
# 45       46960       students_dropout_and_academic_success
# 46       46961                           superconductivity
# 47       46962             taiwanese_bankruptcy_prediction
# 48       46963                            website_phishing
# 49       46964                                wine_quality
# 50       46979                                         jm1
#
#     original_number_features  final_number_features  original_number_rows  \
# 0                          5                      4                  1503
# 1                          9                      1                 32769
# 2                         38                     13                   886
# 3                          7                      3                  1515
# 4                        170                      3                 76000
# 5                         13                      8                 44905
# 6                         10                      6                 10000
# 7                       1776                     11                  3751
# 8                          4                      2                   502
# 9                         19                      5                  5000
# 10                        85                      7                  8261
# 11                         8                      2                   996
# 12                        20                      7                  1000
# 13                        23                      4                 29944
# 14                        21                      8                129880
# 15                         8                      2                   768
# 16                        47                      9                 71518
# 17                         9                      3                 53595
# 18                        10                      7                 10999
# 19                         6                      4                  1499
# 20                         9                      4                 45242
# 21                        10                      3                149354
# 22                        30                      1                  2400
# 23                         6                      5                  1335
# 24                        23                      3                  9871
# 25                      1617                      9                  3825
# 26                         8                      2                 20640
# 27                        12                      6                 19084
# 28                        24                      9                 12587
# 29                        13                      7                  1723
# 30                       212                      8                 50000
# 31                        25                      8                  2039
# 32                         6                      2                   416
# 33                        15                      4                 13776
# 34                       111                      5                  1699
# 35                        86                      9                  7395
# 36                        17                      5                 12205
# 37                         9                      1                 43974
# 38                        64                      1                  5850
# 39                        41                      5                  1051
# 40                      1024                      9                  5259
# 41                         6                      2                   774
# 42                        11                      2                 78053
# 43                        15                      6                  2578
# 44                        60                      7                  3005
# 45                        36                      9                  4424
# 46                        81                      2                 15170
# 47                        94                      2                  6819
# 48                         9                      8                   676
# 49                        12                      3                  5320
# 50                        21                      2                  8824
#
#     final_number_rows  original_density  final_density  initial_r2  \
# 0                1503      1.051902e-03       0.110450         NaN
# 1                  67      5.433146e-21       1.000000         NaN
# 2                   8      6.763895e-16       0.125000         NaN
# 3                  34      5.646737e-10       0.354167         NaN
# 4                  52      0.000000e+00       0.866667         NaN
# 5                2533      5.349773e-12       0.183232         NaN
# 6                 723      4.608577e-12       0.684659         NaN
# 7                 255      0.000000e+00       0.124512         NaN
# 8                 188      1.906424e-04       0.183773         NaN
# 9                 625      2.774980e-36       0.248016         NaN
# 10                 29      4.188386e-67       0.100694         NaN
# 11                452      3.038551e-15       0.208295         NaN
# 12                164      1.403353e-13       0.189815         NaN
# 13                187      4.928384e-57       0.333929         NaN
# 14               8960      1.861241e-18       0.115226         NaN
# 15                283      1.117498e-13       0.354193         NaN
# 16                  7      7.578438e-37       0.109375         NaN
# 17                276      2.616387e-13       0.985714         NaN
# 18               4761      9.032578e-09       0.220417         NaN
# 19                176      1.051149e-05       0.110276         NaN
# 20               3221      5.407391e-16       0.326806         NaN
# 21                323      1.066472e-19       0.119453         NaN
# 22                781      4.281294e-90       1.000000         NaN
# 23                986      5.399227e-04       0.218528         NaN
# 24                184      1.483257e-35       0.135294         NaN
# 25                 63      0.000000e+00       0.123047         NaN
# 26              11032      5.234241e-22       0.251367         NaN
# 27               1731      5.308890e-10       0.183992         NaN
# 28                178      1.445597e-11       0.154514         NaN
# 29                444      1.335653e-10       0.205556         NaN
# 30                 14      0.000000e+00       0.109375         NaN
# 31                 67      3.460081e-32       0.116319         NaN
# 32                 40      7.372958e-06       0.312500         NaN
# 33               2812      1.011417e-44       0.244097         NaN
# 34                 37      1.038332e-68       0.228395         NaN
# 35                 69      9.557813e-23       0.134766         NaN
# 36                374      1.309373e-29       0.144290         NaN
# 37                341      4.142389e-35       1.000000         NaN
# 38               3255     9.503573e-236       1.000307         NaN
# 39                 15      2.447264e-63       0.156250         NaN
# 40                 53     2.925416e-305       0.103516         NaN
# 41                 23      7.633914e-10       0.657143         NaN
# 42               6000      2.075436e-42       1.000000         NaN
# 43                 53      9.400295e-18       0.184028         NaN
# 44               2519      6.838044e-38       0.153748         NaN
# 45                175      1.290519e-40       0.113932         NaN
# 46                 45     3.872284e-287       0.714286         NaN
# 47                389      0.000000e+00       0.510499         NaN
# 48                558      7.727481e-02       0.191358         NaN
# 49               2368      4.506093e-22       0.125503         NaN
# 50                227      3.679058e-50       0.137576         NaN
#
#     accuracy_initial  r2  accuracy
# 0                NaN NaN       NaN
# 1                NaN NaN       NaN
# 2                NaN NaN       NaN
# 3                NaN NaN       NaN
# 4                NaN NaN       NaN
# 5                NaN NaN       NaN
# 6                NaN NaN       NaN
# 7                NaN NaN       NaN
# 8                NaN NaN       NaN
# 9                NaN NaN       NaN
# 10               NaN NaN       NaN
# 11               NaN NaN       NaN
# 12               NaN NaN       NaN
# 13               NaN NaN       NaN
# 14               NaN NaN       NaN
# 15               NaN NaN       NaN
# 16               NaN NaN       NaN
# 17               NaN NaN       NaN
# 18               NaN NaN       NaN
# 19               NaN NaN       NaN
# 20               NaN NaN       NaN
# 21               NaN NaN       NaN
# 22               NaN NaN       NaN
# 23               NaN NaN       NaN
# 24               NaN NaN       NaN
# 25               NaN NaN       NaN
# 26               NaN NaN       NaN
# 27               NaN NaN       NaN
# 28               NaN NaN       NaN
# 29               NaN NaN       NaN
# 30               NaN NaN       NaN
# 31               NaN NaN       NaN
# 32               NaN NaN       NaN
# 33               NaN NaN       NaN
# 34               NaN NaN       NaN
# 35               NaN NaN       NaN
# 36               NaN NaN       NaN
# 37               NaN NaN       NaN
# 38               NaN NaN       NaN
# 39               NaN NaN       NaN
# 40               NaN NaN       NaN
# 41               NaN NaN       NaN
# 42               NaN NaN       NaN
# 43               NaN NaN       NaN
# 44               NaN NaN       NaN
# 45               NaN NaN       NaN
# 46               NaN NaN       NaN
# 47               NaN NaN       NaN
# 48               NaN NaN       NaN
# 49               NaN NaN       NaN
# 50               NaN NaN       NaN

# %%
np.array(final_table['original_density'])
# Out:
# array([1.05190224e-003, 5.43314649e-021, 6.76389453e-016, 5.64673705e-010,
#        0.00000000e+000, 5.34977297e-012, 4.60857693e-012, 0.00000000e+000,
#        1.90642419e-004, 2.77498011e-036, 4.18838624e-067, 3.03855133e-015,
#        1.40335277e-013, 4.92838397e-057, 1.86124145e-018, 1.11749823e-013,
#        7.57843832e-037, 2.61638676e-013, 9.03257841e-009, 1.05114945e-005,
#        5.40739138e-016, 1.06647219e-019, 4.28129354e-090, 5.39922736e-004,
#        1.48325730e-035, 0.00000000e+000, 5.23424119e-022, 5.30889048e-010,
#        1.44559699e-011, 1.33565265e-010, 0.00000000e+000, 3.46008068e-032,
#        7.37295826e-006, 1.01141724e-044, 1.03833218e-068, 9.55781348e-023,
#        1.30937265e-029, 4.14238883e-035, 9.50357310e-236, 2.44726371e-063,
#        2.92541586e-305, 7.63391402e-010, 2.07543556e-042, 9.40029535e-018,
#        6.83804444e-038, 1.29051926e-040, 3.87228427e-287, 0.00000000e+000,
#        7.72748057e-002, 4.50609348e-022, 3.67905845e-050])

# %%
values = np.array(final_table['original_density'])
log_values = np.log10(values[values > 0])

# Create dataframe
df = pd.DataFrame({"log10(value)": log_values})

# Plot histogram of log-values
fig = px.histogram(df, x="log10(value)", labels={'log10(value)':'log10(original_density)'}, nbins=50, text_auto=True, title="Original density of the datasets from TabArena.")
fig.update_layout(bargap=0.2)

fig.show()

# %%
import plotly.express as px
fig = px.histogram(x=final_table['original_density'], 
                   labels={'x':'Original_density'}, text_auto=True, title='Original density of datasets from TabArena')
fig.update_layout(bargap=0.2)
fig.show()

# %%
import plotly.express as px
fig = px.histogram(x=final_table['final_density'], title='Final density of datasets from TabArena after features dropping process.',
                   labels={'x':'final_density'}, text_auto=True)
fig.update_layout(bargap=0.2)
fig.show()

# %%
from TabArenaIterator import TabArenaIterator
from autogluon.tabular import TabularPredictor
import os
import pandas as pd
import numpy as np

models= ['XGB', 'NN_TORCH']

final_table = pd.DataFrame(columns=['dataset_id', 'dataset_name', 
                                    'original_number_features', 'final_number_features',
                                    'original_number_rows', 'final_number_rows',
                                    'original_density', 'final_density'])

for model in models:
    final_table['initial_' + model + '_r2'] = None
    final_table['initial_' + model + '_accuracy'] = None
    final_table['final_' + model + '_r2'] = None
    final_table['final_' + model + '_accuracy'] = None

tabArenaURL = 'https://raw.githubusercontent.com/TabArena/tabarena_dataset_curation/refs/heads/main/dataset_creation_scripts/metadata/tabarena_dataset_metadata.csv'
iterator = TabArenaIterator(tabArenaURL)
for row, df in iterator:
    print(row['dataset_id'])

    # Obtain the dense df and informations about the changes
    dense_df, infos = getDensitiesPlot(df, row['target_feature'], density_threshold=0.1, show_fig=False)

    # Train the initial models and get the metrics
    for model in models:
        metric, result = trainAutogluonModels(df, 'AutoGluonModels/' + 'initial_' + model + '_' + row['dataset_name'], 
                                                        row['problem_type'], row['target_feature'], {model:{}})
        infos['initial_' + model + '_' + metric] = result

    # If the dense df does not fulfill the requirement, skip to the next dataset
    if infos['final_number_features'] < 3 or infos['final_number_rows'] < 30:
        print('Feature or obaservations not fulfill requirements.')
        continue
    
    # Extract the target feature to the dense_df
    dense_df[row['target_feature']] = df[row['target_feature']].iloc[dense_df.index,]
    dense_df = dense_df.reset_index(drop=True)
    '''
    # Split the train (70%) and test (30%) dataset
    train_data = dense_df.iloc[:int(len(dense_df) * 0.7), ]
    test_data = dense_df.iloc[int(len(dense_df) * 0.7):, ]

    # Set the path where the model should be saved 
    path = 'AutoGluonModels/' + row['dataset_name']

    # Choose the metric for regression or classification
    if row['problem_type'] == 'regression':
        metric = 'r2'
    else:
        metric = 'accuracy' 

    # If the path (the model) already exists, load the model, if not, train the model
    if os.path.isdir(path):
        print('Model already exists. Loading...')
        predictor = TabularPredictor.load(path)
    else:
        print('Train a new model...')
        predictor = TabularPredictor(label=row['target_feature'], path=path, 
                                     eval_metric=metric, problem_type=row['problem_type'],
                                     verbosity=0).fit(train_data)
    
    # Set the result and other informations about the dataset
    result_metric = predictor.evaluate(test_data).get(metric)
    '''

    for model in models:
        metric, result = trainAutogluonModels(dense_df, 'AutoGluonModels/' + 'final_' + model + '_' + row['dataset_name'], 
                                                        row['problem_type'], row['target_feature'], {model:{}})
        infos['final_' + model + '_' + metric] = result

    infos['dataset_id'] = row['dataset_id']
    infos['dataset_name'] = row['dataset_name']


    # Append the row to the final table
    final_table.loc[len(final_table)] = infos
